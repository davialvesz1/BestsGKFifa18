# %%
import pandas as pd

# %%
df = pd.read_csv('fifa.csv')

# %%
df1 = df[['Name','Club','Nationality','Wage','Age','Position','Overall']]

#df1.iloc[0,0]

# %%
df2 = df1.loc[df1['Position']=='GK'].sort_values('Overall',ascending = False,) 
df2.head(10)
# Out:
#              Name                 Club Nationality   Wage  Age Position  \
# 3          De Gea    Manchester United       Spain  €260K   27       GK
# 9        J. Oblak      Atlético Madrid    Slovenia   €94K   25       GK
# 18  M. ter Stegen         FC Barcelona     Germany  €240K   26       GK
# 19    T. Courtois          Real Madrid     Belgium  €240K   26       GK
# 22       M. Neuer    FC Bayern München     Germany  €130K   32       GK
# 37      H. Lloris    Tottenham Hotspur      France  €150K   31       GK
# 40  S. Handanovič                Inter    Slovenia  €110K   33       GK
# 41      G. Buffon  Paris Saint-Germain       Italy   €77K   40       GK
# 46       K. Navas          Real Madrid  Costa Rica  €195K   31       GK
# 57        Ederson      Manchester City      Brazil  €125K   24       GK
#
#     Overall
# 3        91
# 9        90
# 18       89
# 19       89
# 22       89
# 37       88
# 40       88
# 41       88
# 46       87
# 57       86

# %%
df2.to_csv('GkList.csv',index=False)
